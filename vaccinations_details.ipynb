# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedabdulhaseeb07/vacciations_records/blob/main/vaccinations_details.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/vaccinations.csv")

# %%
df
# Out:
#            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 185458     Zimbabwe      ZWE  2022-10-05          12219760.0
# 185459     Zimbabwe      ZWE  2022-10-06                 NaN
# 185460     Zimbabwe      ZWE  2022-10-07                 NaN
# 185461     Zimbabwe      ZWE  2022-10-08                 NaN
# 185462     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# ...

# %%
df.head(10)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# ...

# %%
df.tail(10)
# Out:
#         location iso_code        date  total_vaccinations  people_vaccinated  \
# 185453  Zimbabwe      ZWE  2022-09-30                 NaN                NaN
# 185454  Zimbabwe      ZWE  2022-10-01          12212594.0          6435008.0
# 185455  Zimbabwe      ZWE  2022-10-02          12214870.0          6435481.0
# 185456  Zimbabwe      ZWE  2022-10-03          12216848.0          6435970.0
# 185457  Zimbabwe      ZWE  2022-10-04                 NaN                NaN
# 185458  Zimbabwe      ZWE  2022-10-05          12219760.0          6436704.0
# 185459  Zimbabwe      ZWE  2022-10-06                 NaN                NaN
# 185460  Zimbabwe      ZWE  2022-10-07                 NaN                NaN
# 185461  Zimbabwe      ZWE  2022-10-08                 NaN                NaN
# 185462  Zimbabwe      ZWE  2022-10-09          12222754.0          6437808.0
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# ...

# %%
df.shape
# Out:
# (185463, 16)

# %%
df.info
# Out:
# <bound method DataFrame.info of            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 185458     Zimbabwe      ZWE  2022-10-05          12219760.0
# 185459     Zimbabwe      ZWE  2022-10-06                 NaN
# 185460     Zimbabwe      ZWE  2022-10-07                 NaN
# 185461     Zimbabwe      ZWE  2022-10-08                 NaN
# 185462     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 185458     Zimbabwe      ZWE  2022-10-05          12219760.0
# 185459     Zimbabwe      ZWE  2022-10-06                 NaN
# 185460     Zimbabwe      ZWE  2022-10-07                 NaN
# 185461     Zimbabwe      ZWE  2022-10-08                 NaN
# 185462     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# ...

# %%
df.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'daily_vaccinations_per_million', 'daily_people_vaccinated',
#        'daily_people_vaccinated_per_hundred'],
#       dtype='object')

# %%
df.location
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 185458       Zimbabwe
# 185459       Zimbabwe
# 185460       Zimbabwe
# 185461       Zimbabwe
# 185462       Zimbabwe
# Name: location, Length: 185463, dtype: object

# %%
df.total_vaccinations
# Out:
# 0                0.0
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#              ...
# 185458    12219760.0
# 185459           NaN
# 185460           NaN
# 185461           NaN
# 185462    12222754.0
# Name: total_vaccinations, Length: 185463, dtype: float64

# %%
df.people_vaccinated
# Out:
# 0               0.0
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 185458    6436704.0
# 185459          NaN
# 185460          NaN
# 185461          NaN
# 185462    6437808.0
# Name: people_vaccinated, Length: 185463, dtype: float64

# %%
df.total_boosters
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 185458    1032952.0
# 185459          NaN
# 185460          NaN
# 185461          NaN
# 185462    1033676.0
# Name: total_boosters, Length: 185463, dtype: float64
